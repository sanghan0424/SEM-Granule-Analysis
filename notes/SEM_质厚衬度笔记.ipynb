# %% [markdown]
# # SEM质厚衬度笔记
# ## 核心结论
# 1. 质厚衬度 = 原子序数衬度 + 厚度衬度；
# 2. **原子序数↑ → 电子散射↑ → SEM图像亮度↑**；
# 3. **样品厚度↑ → 电子散射↑ → SEM图像亮度↑**；
# 4. 实例：相同厚度的Au颗粒（序数79）比C颗粒（序数6）在SEM图中更亮。
#
# ## 个人标注（可补充）
# - （比如：质厚衬度是SEM分析颗粒成分的核心依据）
